# %% [raw]
# data types- python dynamicalyy type

# %% [raw]
# int
# float
# string
# bool
# tuple
# dictionary
# set
# complex

# %%
a = 10

# %%
b= "python"

# %%
c = 23.5

# %%
type(c) #predefined
# Out:
# float

# %%
type (a)
# Out:
# int

# %%
d = '45'

# %%
type(d)
# Out:
# str

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
b = False

# %%
type(b)
# Out:
# bool

# %%
a = 4 + 15j

# %%
a
# Out:
# (4+15j)

# %%
type(a)
# Out:
# complex

# %%
a.imag
# Out:
# 15.0

# %%
a.real
# Out:
# 4.0

# %%
# tuple
# dictionary
# set
# list

# %%
a = 10, 20 ,30 ,40

# %%
a
# Out:
# (10, 20, 30, 40)

# %%
a = () #tuple

# %%
type(a)
# Out:
# tuple

# %%
t =(23)

# %%
type(t) #it gave int because you cannot take single value so you can take 23, in such case use comma
# Out:
# int

# %% [raw]
# you can store any type of data in tuple

# %%
t = (12, "python", True, 54.34)

# %%
type(t)
# Out:
# tuple

# %%
a = []

# %%
type(a)
# Out:
# list

# %% [raw]
# can use empty list
# list vs tuple: [] (), use empty string and single value in list but in tuple need to use comma for single value

# %%
l = [12, "python", True, 54.34]

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# [12, 'python', True, 54.34]

# %% [raw]
# s = {}

# %%
type(s)
# Out:
# dict

# %% [raw]
# in python empty{} represent dictionanry
# cannot create empty set

# %%
s = {23}

# %%
type(s)
# Out:
# set

# %%
s= {"Hello", 34, 2, 2 ,56.6, True}

# %%
type(s)
# Out:
# set

# %%
 s #it gave unique value
# Out:
# {2, 34, 56.6, 'Hello', True}

# %% [raw]
# set give unique value you cant print duplicate value

# %%
d = {30}

# %%
d
# Out:
# {30}

# %% [raw]
# type(d)

# %%
d = {"key": "value", "name":"john", "age": 23,"contact":234}

# %%
d
# Out:
# {'key': 'value', 'name': 'john', 'age': 23, 'contact': 234}

# %%
type(d)
# Out:
# dict

# %%
s = "python"
